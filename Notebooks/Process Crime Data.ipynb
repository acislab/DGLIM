# %% [markdown]
# # Process Crime Data

# %%
import pickle
import numpy as np
import pandas as pd
import csv
import pandas as pd
import re # Regular Expressions
import math

from peewee import *
from Models import *
from geopy.distance import vincenty
from datetime import datetime

import dglim

# %% [markdown]
# # Load Datasets

# %%
# TODO: I'd like to avoid using master_df, but the coordinates in act_bus_df are not reliable
# TODO: Maybe generate a separate dataset just for coordinates?
master_df = dglim.loadData('Master Dataset')

act_bus_df = pd.read_excel("../City_Data/DGLIM_survey_data/city of Gainesville active businesses dataset with uniqueid (fixed coords).xlsx")
crime_incidents_df = pd.read_csv("../City_Data/Crime_Incidents_2011_-_Present.csv")

# %% [markdown]
# # Process Crime Data

# %%
print "Total number of crimes:", len(crime_incidents_df)
# Out:
# Total number of crimes: 123590

# %% [markdown]
# ** Format GPS coordinates **

# %%
def extractCoordinates(string):
    # Extract string coordinates from location entry
    string = str(string) # Convert unicode to str if necessary
    values_list = [x for x in re.split('[()]', string) if x != '']

    if len(values_list) > 1:
        str_coords = values_list[len(values_list) - 1]
        coords = str_coords.split(',')
        return [float(coords[0]), float(coords[1])]
    else:
        return [np.nan, np.nan]

# %%
crime_incidents_df['Latitude'], crime_incidents_df['Longitude'] = [np.nan, np.nan]
crime_incidents_df[['Latitude', 'Longitude']] = map(lambda x: extractCoordinates(x), crime_incidents_df['Location'].tolist())

# %% [markdown]
# ** Sort coordinates by latitude first, then longitude **

# %%
crime_incidents_df.dropna(inplace=True)
crime_incidents_df.sort_values(by=['Latitude', 'Longitude'], inplace=True)
crime_incidents_df.reset_index(inplace=True, drop=True)

# %% [markdown]
# ** Gather crimes within 500 meters of each business **

# %%
pd.Series(crime_incidents_df['Latitude'].value_counts())
# Out:
# 29.662839    1532
# 29.661941     847
# 29.624470     827
# 29.652108     756
# 29.651923     587
# 29.659540     558
# 29.659421     538
# 29.633966     450
# 29.708669     427
# 29.652738     405
# 29.710005     392
# 29.657548     383
# 29.652098     372
# 29.682581     369
# 29.659383     357
# 29.670571     342
# 29.651934     328
# 29.659533     326
# 29.659533     321
# 29.659564     314
# 29.659173     312
# 29.651979     311
# 29.688433     295
# 29.634364     294
# 29.684060     285
# 29.636855     281
# 29.659729     281
# 29.634011     272
# 29.642844     272
# 29.659278     261
#              ...
# 29.944414       1
# 29.629997       1
# 29.614497       1
# 29.668117       1
# 29.617423       1
# 29.714387       1
# 29.724723       1
# 29.629436       1
# 29.649440       1
# 29.632217       1
# 29.692181       1
# 29.634181       1
# 29.693426       1
# 29.722317       1
# 29.831061       1
# 29.620671       1
# 29.661643       1
# 29.651031       1
# 29.639070       1
# 29.655950       1
# 29.629031       1
# 29.635904       1
# 29.671904       1
# 29.674891       1
# 29.645740       1
# 29.603038       1
# 29.650101       1
# 29.694403       1
# 29.643350       1
# 29.622506       1
# Name: Latitude, Length: 23370, dtype: int64

# %%
lat_column_index = crime_incidents_df.columns.get_loc('Latitude')
lng_column_index = crime_incidents_df.columns.get_loc('Longitude')

# %%
crime_incidents_df
# Out:
#                ID                                      Incident Type  \
# 0       213000051                           HARASSING/ OBSCENE CALLS
# 1       213002719                                     IDENTITY THEFT
# 2       213020222                                ASSIST OTHER AGENCY
# 3       514000376                                     DRUG VIOLATION
# 4       514000517                                     DRUG VIOLATION
# 5       514000519                               DRUG VIOLATION (SID)
# 6       511000080                                     DRUG VIOLATION
# 7       214024443                                SUSPICIOUS INCIDENT
# 8       213019493                                     WARRANT ARREST
# 9       511000493                                        INFORMATION
# 10      511000007                               DRUG VIOLATION (SID)
# 11      511000050                                     DRUG VIOLATION
# 12      511000044                                     DRUG VIOLATION
# 13      511000116                               DRUG VIOLATION (SID)
# 14      511000112                               DRUG VIOLATION (SID)
# 15      511000160                                     DRUG VIOLATION
# 16      511000191          WEAPONS VIOLATION (POSSESSING/CONCEALING)
# 17      511000254                                        INFORMATION
# 18      511000296                                     DRUG VIOLATION
# 19      511000298                               DRUG VIOLATION (SID)
# 20      511000351                                     DRUG VIOLATION
# 21      511000391                 DRUG POSS. OF CONTROLLED SUBSTANCE
# 22      511000459                                     DRUG VIOLATION
# 23      511000495                                        INFORMATION
# 24      511000563                                        INFORMATION
# 25      511000703                                ASSIST OTHER AGENCY
# 26      511000691                                     DRUG VIOLATION
# 27      511000800                                     DRUG VIOLATION
# 28      512000059  POSSESS FIREARM/CONCEALED WEAPON BY CONVICTED ...
# 29      512000058                                     DRUG VIOLATION
# ...           ...                                                ...
# 121957  211011567                                ASSIST OTHER AGENCY
# 121958  212007276                                     DRUG VIOLATION
# 121959  211006487                                ASSIST OTHER AGENCY
# 121960  218002443                             SICK / INJURED  PERSON
# 121961  517000073                                ASSIST OTHER AGENCY
# 121962  512000551                                        INFORMATION
# 121963  214003390                                ASSIST OTHER AGENCY
# 121964  211020272                                ASSIST OTHER AGENCY
# 121965  212012607                                ASSIST OTHER AGENCY
# 121966  212012603                                ASSIST OTHER AGENCY
# 121967  212012606                                ASSIST OTHER AGENCY
# 121968  212012605                                ASSIST OTHER AGENCY
# 121969  212012604                                ASSIST OTHER AGENCY
# 121970  212012600                                ASSIST OTHER AGENCY
# 121971  212012592                                ASSIST OTHER AGENCY
# 121972  212012601                                ASSIST OTHER AGENCY
# 121973  212012602                                ASSIST OTHER AGENCY
# 121974  213022763                           HARASSING/ OBSCENE CALLS
# 121975  215012936                                    COMPUTER CRIMES
# 121976  217004638                                 DCF INVESTIGATIONS
# 121977  211013535                            DAMAGE TO CITY PROPERTY
# 121978  215012145                                 DCF INVESTIGATIONS
# 121979  212020081                                 DCF INVESTIGATIONS
# 121980  217015950                                ASSIST OTHER AGENCY
# 121981  216016750                                ASSIST OTHER AGENCY
# 121982  216003592                                ASSIST OTHER AGENCY
# 121983  216020612                               THEFT PETIT - RETAIL
# 121984  216020989                               THEFT PETIT - RETAIL
# 121985  216018395                              THEFT GRAND  - RETAIL
# 121986  616002646                                      LOST PROPERTY
#
#                    Report Date            Offense Date           City State  \
# 0       01/01/2013 09:24:20 PM  01/01/2013 05:00:19 PM          MIAMI    FL
# 1       02/08/2013 11:51:10 AM  10/24/2012 12:00:00 AM        HIALEAH    FL
# 2       10/09/2013 04:02:00 AM  10/09/2013 01:40:59 AM       HAWTHORN    FL
# 3       11/17/2014 01:40:33 PM  11/17/2014 01:40:32 PM         COUNTY    FL
# 4       11/18/2014 11:58:01 AM  11/18/2014 11:58:00 AM         COUNTY    FL
# 5       12/04/2014 09:35:15 AM  12/02/2014 02:41:14 PM         COUNTY    FL
# 6       02/28/2011 03:22:03 PM  02/28/2011 03:00:02 PM         COUNTY    FL
# 7       12/10/2014 10:31:04 AM  12/10/2014 10:31:03 AM         COUNTY    FL
# 8       09/28/2013 06:25:25 PM  09/28/2013 06:25:00 PM         COUNTY    FL
# 9       08/21/2011 08:30:35 PM  08/19/2011 09:45:34 AM         COUNTY    FL
# 10      01/15/2011 04:09:03 PM  01/14/2011 04:00:00 PM         COUNTY    FL
# 11      02/11/2011 04:00:10 PM  02/10/2011 01:30:00 PM         COUNTY    FL
# 12      02/02/2011 12:09:19 PM  02/01/2011 08:10:18 PM         COUNTY    FL
# 13      04/11/2011 04:24:00 PM  04/11/2011 04:24:00 PM         COUNTY    FL
# 14      04/05/2011 09:28:17 AM  04/05/2011 08:28:16 AM         COUNTY    FL
# 15      04/01/2011 03:33:02 PM  03/28/2011 05:10:01 PM         COUNTY    FL
# 16      04/14/2011 04:28:55 PM  04/14/2011 04:28:54 PM         COUNTY    FL
# 17      05/04/2011 07:20:44 PM  05/04/2011 07:20:43 PM         COUNTY    FL
# 18      05/23/2011 11:15:29 AM  05/23/2011 03:00:28 AM         COUNTY    FL
# 19      05/26/2011 09:14:07 AM  05/26/2011 09:14:06 AM         COUNTY    FL
# 20      06/06/2011 05:00:15 PM  06/06/2011 01:00:14 PM         COUNTY    FL
# 21      06/22/2011 06:44:58 PM  06/21/2011 05:08:57 PM         COUNTY    FL
# 22      08/04/2011 09:05:53 AM  08/04/2011 09:05:52 AM         COUNTY    FL
# 23      08/24/2011 11:01:18 AM  08/23/2011 07:47:17 PM         COUNTY    FL
# 24      09/19/2011 11:01:33 AM  09/15/2011 11:01:32 AM         COUNTY    FL
# 25      11/09/2011 06:53:39 PM  11/09/2011 06:05:38 PM         COUNTY    FL
# 26      11/02/2011 03:50:57 PM  11/02/2011 02:50:56 PM         COUNTY    FL
# 27      12/28/2011 11:27:45 AM  12/28/2011 11:27:44 AM         COUNTY    FL
# 28      01/31/2012 09:14:23 PM  01/31/2012 08:12:22 PM         COUNTY    FL
# 29      01/31/2012 04:42:46 PM  01/31/2012 04:42:45 PM         COUNTY    FL
# ...                        ...                     ...            ...   ...
# 121957  06/07/2011 03:14:45 PM  04/26/2011 09:30:00 PM   ST AUGUSTINE    FL
# 121958  04/08/2012 06:56:58 PM  04/08/2012 06:15:57 PM            NEW    FL
# 121959  03/31/2011 04:22:22 PM  03/31/2011 01:10:00 PM            NEW    FL
# 121960  02/08/2018 10:32:23 AM  02/07/2018 12:00:22 PM       FT WHITE    FL
# 121961  02/13/2017 09:09:56 AM  02/07/2017 06:00:00 AM    LAKE BUTLER    FL
# 121962  12/06/2012 10:08:26 AM  12/05/2012 10:08:25 AM      LAKE CITY    FL
# 121963  02/20/2014 02:26:00 PM  02/18/2014 10:40:59 AM      LAKE CITY    FL
# 121964  09/30/2011 03:04:32 PM  09/30/2011 03:04:31 PM    ORANGE PARK    FL
# 121965  06/21/2012 11:43:38 AM  03/28/2012 12:00:00 AM    ORANGE PARK    FL
# 121966  06/21/2012 11:27:24 AM  03/28/2012 12:00:00 AM    ORANGE PARK    FL
# 121967  06/21/2012 11:40:31 AM  03/28/2012 12:00:00 AM    ORANGE PARK    FL
# 121968  06/21/2012 11:35:40 AM  03/28/2012 12:00:00 AM    ORANGE PARK    FL
# 121969  06/21/2012 11:31:57 AM  03/28/2012 12:00:00 AM    ORANGE PARK    FL
# 121970  06/21/2012 09:48:21 AM  06/13/2012 09:48:20 AM    PANAMA CITY    FL
# 121971  06/21/2012 07:45:48 AM  06/14/2012 01:35:00 AM    PANAMA CITY    FL
# 121972  06/21/2012 09:59:34 AM  06/13/2012 12:00:00 AM    PANAMA CITY    FL
# 121973  06/21/2012 10:15:59 AM  06/13/2012 12:00:00 AM    PANAMA CITY    FL
# 121974  11/15/2013 08:54:07 AM  11/15/2013 03:00:00 AM   JACKSONVILLE    FL
# 121975  07/09/2015 11:44:21 AM  05/27/2015 10:12:00 PM   JACKSONVILLE    FL
# 121976  03/14/2017 12:47:25 PM  03/14/2017 12:47:24 PM   JACKSONVILLE    FL
# 121977  07/05/2011 11:51:13 AM  06/26/2011 02:30:00 PM      PENSACOLA    FL
# 121978  06/26/2015 01:37:47 PM  04/10/2015 12:00:46 PM       CALLAHAN    FL
# 121979  09/29/2012 04:13:57 PM  08/01/2010 12:01:56 AM         MILTON    FL
# 121980  08/28/2017 10:30:00 AM  08/27/2017 01:00:00 AM  LAS VEGAS, NV    FL
# 121981  09/10/2016 05:18:00 PM  09/10/2016 05:18:00 PM    GAINESVILLE    FL
# 121982  02/24/2016 02:09:00 AM  02/24/2016 01:50:00 AM        UNKNOWN    FL
# 121983  11/03/2016 04:41:07 PM  11/03/2016 12:07:00 PM    GAINESVILLE    FL
# 121984  11/09/2016 11:07:31 AM  11/09/2016 11:00:00 AM    GAINESVILLE    FL
# 121985  10/03/2016 05:23:01 PM  08/21/2016 01:20:00 PM    GAINESVILLE    FL
# 121986  10/08/2016 12:00:00 AM  10/06/2016 12:00:00 AM    GAINESVILLE    FL
#
#                                                  Location   Latitude  \
# 0       5449 SW 86TH ST\nMIAMI, FL\n(25.69144767000006...  25.691448
# 1       134 E 9TH ST\nHIALEAH, FL\n(25.830013015000077...  25.830013
# 2       21419 SE 61ST AVE\nHAWTHORN, FL\n(26.733470912...  26.733471
# 3       377 MM SR 93 SOUTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 4       380 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 5       380 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 6       SR 93 392 SB\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 7       3333 NE 39TH AVE\nCOUNTY, FL\n(26.774380653000...  26.774381
# 8       220 S MAIN ST\nCOUNTY, FL\n(26.774380653000037...  26.774381
# 9       SR 93 MM 403 SB\nCOUNTY, FL\n(26.7743806530000...  26.774381
# 10      SR 93 MM377 NB\nCOUNTY, FL\n(26.77438065300003...  26.774381
# 11      SR 93 374 SB\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 12      SR 93 MM 375 NB\nCOUNTY, FL\n(26.7743806530000...  26.774381
# 13      SR 93 MM 380 NB\nCOUNTY, FL\n(26.7743806530000...  26.774381
# 14      SR 93 374 SB\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 15      377 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 16      MM 377 SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 17      SR 93 379 MM\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 18      378MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.774380...  26.774381
# 19      SR 93 376 MM\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 20      375 MM SR 93 SOUTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 21      382 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 22      374 MM SR 93 SOUTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 23      SR 93 MM 393 SB\nCOUNTY, FL\n(26.7743806530000...  26.774381
# 24      SR 93 399 NB\nCOUNTY, FL\n(26.774380653000037,...  26.774381
# 25      374 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 26      375 MM SR 93 SOUTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 27      SR 93 392 MM SB\nCOUNTY, FL\n(26.7743806530000...  26.774381
# 28      379 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# 29      380 MM SR 93 NORTHBOUND\nCOUNTY, FL\n(26.77438...  26.774381
# ...                                                   ...        ...
# 121957  269 PORTA ROSA CIR\nST AUGUSTINE, FL\n(29.9527...  29.952716
# 121958  17280 W NEWBERRY RD\nNEW, FL\n(29.961383729000...  29.961384
# 121959  12200 W NEWBERRY RD\nNEW, FL\n(29.961383729000...  29.961384
# 121960  231 SW HACKBERRY GLN\nFT WHITE, FL\n(29.976966...  29.976966
# 121961  162 SW 8TH AVE\nLAKE BUTLER, FL\n(30.022367, -...  30.022367
# 121962  233 SW GULL DR\nLAKE CITY, FL\n(30.05469066600...  30.054691
# 121963  439 SW MICHEGAN ST\nLAKE CITY, FL\n(30.1565085...  30.156509
# 121964  410 BLANDING BLVD\nORANGE PARK, FL\n(30.162728...  30.162729
# 121965  212 BLANDING BOULEVARD\nORANGE PARK, FL\n(30.1...  30.176150
# 121966  212 BLANDING BOULEVARD\nORANGE PARK, FL\n(30.1...  30.176150
# 121967  212 BLANDING BOULEVARD\nORANGE PARK, FL\n(30.1...  30.176150
# 121968  212 BLANDING BOULEVARD\nORANGE PARK, FL\n(30.1...  30.176150
# 121969  212 BLANDING BLVD\nORANGE PARK, FL\n(30.176150...  30.176150
# 121970  3421 NORTH HIGHWAY 77\nPANAMA CITY, FL\n(30.21...  30.210721
# 121971  3421 FL 77\nPANAMA CITY, FL\n(30.2107211470000...  30.210721
# 121972  3421 NORTH HIGHWAY 77\nPANAMA CITY, FL\n(30.21...  30.210721
# 121973  3421 NORTH HIGHWAY 77\nPANAMA CITY, FL\n(30.21...  30.210721
# 121974  1116 KNOLL DR W\nJACKSONVILLE, FL\n(30.3031756...  30.303176
# 121975  501 E BAY ST.\nJACKSONVILLE, FL\n(30.324667991...  30.324668
# 121976  4045 GRISSOM DR\nJACKSONVILLE, FL\n(30.374989,...  30.374989
# 121977  3755 POTOSI RD\nPENSACOLA, FL\n(30.48488471100...  30.484885
# 121978  54332 JONAS DRIVE\nCALLAHAN, FL\n(30.539054632...  30.539055
# 121979  5770 E MILTON RD\nMILTON, FL\n(30.641467455000...  30.641467
# 121980  3570 S LAS VEGAS BLVD\nLAS VEGAS, NV, FL\n(36....  36.115353
# 121981  1910 STADIUM RD\nGAINESVILLE, FL\n(38.029032, ...  38.029032
# 121982     COPELAND\nUNKNOWN, FL\n(41.796553, -85.006456)  41.796553
# 121983  3101 CLARKE BUTLER BLVD\nGAINESVILLE, FL\n(44....  44.010402
# 121984  3101 CLARKE BUTLER BLVD\nGAINESVILLE, FL\n(44....  44.010402
# 121985  3101 CLARKE BUTLER BLVD\nGAINESVILLE, FL\n(44....  44.010402
# 121986  3101 CLARKE BUTLER BLVD\nGAINESVILLE, FL\n(44....  44.010402
#
#          Longitude
# 0       -80.282131
# 1       -80.278180
# 2       -80.229968
# 3       -80.112507
# 4       -80.112507
# 5       -80.112507
# 6       -80.112507
# 7       -80.112507
# 8       -80.112507
# 9       -80.112507
# 10      -80.112507
# 11      -80.112507
# 12      -80.112507
# 13      -80.112507
# 14      -80.112507
# 15      -80.112507
# 16      -80.112507
# 17      -80.112507
# 18      -80.112507
# 19      -80.112507
# 20      -80.112507
# 21      -80.112507
# 22      -80.112507
# 23      -80.112507
# 24      -80.112507
# 25      -80.112507
# 26      -80.112507
# 27      -80.112507
# 28      -80.112507
# 29      -80.112507
# ...            ...
# 121957  -81.489809
# 121958  -82.265016
# 121959  -82.265016
# 121960  -82.666724
# 121961  -82.347223
# 121962  -82.703701
# 121963  -82.645581
# 121964  -81.747562
# 121965  -81.744163
# 121966  -81.744163
# 121967  -81.744163
# 121968  -81.744163
# 121969  -81.744163
# 121970  -85.649693
# 121971  -85.649693
# 121972  -85.649693
# 121973  -85.649693
# 121974  -81.780037
# 121975  -81.650705
# 121976  -81.605778
# 121977  -87.181552
# 121978  -81.770028
# 121979  -86.973853
# 121980 -115.172969
# 121981  -78.513811
# 121982  -85.006456
# 121983 -117.007912
# 121984 -117.007912
# 121985 -117.007912
# 121986 -117.007912
#
# [121987 rows x 9 columns]

# %%
def countCrimesWithinRadius(center_coords, year_set, search_radius=500):

    total = pd.Series(index=year_set, data=0)

    # Use fixed values to find meters between lat/lng coordinates
    # The area of interest is small enough that variations in longitude at different latitudes can be ignored
    lat_scale = 110846.58 # Approximate length in meters of one degree of latitude in Gainesville
    lng_scale = 96821.46 # Approximate length in meters of one degree of longitude in Gainesville
    search_radius_squared = search_radius ** 2 # meters^2
    lat_search_threshold = search_radius/lat_scale

    # Find indices of the northernmost and southernmost crimes whose latitudes are close enough to the business to
    # potentially be within the search radius
    start_lat_index = crime_incidents_df['Latitude'].searchsorted(
        value=center_coords[0] - lat_search_threshold, side='left')[0]
    stop_lat_index = crime_incidents_df['Latitude'].searchsorted(
        value=center_coords[0] + lat_search_threshold, side='right')[0]

    if (start_lat_index >= len(crime_incidents_df)):
        return total

    start_lat = crime_incidents_df.get_value(start_lat_index, 'Latitude')
    stop_lat = crime_incidents_df.get_value(stop_lat_index, 'Latitude')

    lat_slice_df = crime_incidents_df[start_lat_index:stop_lat_index]

    # For each latitude, do the same for longitudes
    # Note: lat_index is an integer index, i.e. "0" indicates the first entry in lat_slice_df
    lat_slice_df['Latitude'].value_counts()
    unique_lat_indices = lat_slice_df['Latitude'].drop_duplicates().index
    for lat_index in unique_lat_indices:
        lat_value = lat_slice_df.get_value(lat_index, 'Latitude')
        lng_slice_df = lat_slice_df[lat_slice_df['Latitude'] == lat_value]

        # Calculate max difference in longitude where crimes are still within the search radius
        lng_search_threshold = \
            math.sqrt(search_radius_squared - (abs(lat_value - center_coords[0]) * lat_scale) ** 2) / lng_scale

        # Get range of indices that are within the lower/upper longitude bounds
        start_lng_pos = lng_slice_df['Longitude'].searchsorted(
            value=center_coords[1] - lng_search_threshold, side='left')[0]
        stop_lng_pos = lng_slice_df['Longitude'].searchsorted(
            value=center_coords[1] + lng_search_threshold, side='right')[0]

        # All indices must be for crimes within the specified radius
        for pos in range(start_lng_pos, stop_lng_pos):
            crime_date = datetime.strptime(lng_slice_df.iloc[pos]['Offense Date'], '%m/%d/%Y %I:%M:%S %p')
            year = crime_date.year
            if year in total.index:
                total[year] += 1

    return total

# %%
# Get coordinates for each business
# act_bus_df['Coords'] = act_bus_df['Location'].apply(extractCoordinates)

year_set = range(2011, 2018);

# Count crimes near each business
temp_df = pd.DataFrame(index=master_df.index)
temp_df['Coords'] = zip(master_df['Latitude'], master_df['Longitude'])
crime_counts_df = temp_df['Coords'].apply(lambda x: countCrimesWithinRadius(x, year_set, 500))

# Save results
dglim.saveData(crime_counts_df, 'Crimes Within 500m by DGLIM ID')

# %%
crime_counts_df
# Out:
#           2011  2012  2013  2014  2015  2016  2017
# DGLIM ID
# 16          79    84    79    65    32    48    64
# 17         675   625   596   543   337   532   564
# 24          63    71    73    80    31    49    44
# 25        1174  1170   957   711   393   572   642
# 38         210   205   172   164   120   173   148
# 43         789   799   603   549   273   425   428
# 51          53    62    52    65    25    67    43
# 52          80    88   114    78    49    86    85
# 59         325   293   304   222   105   216   179
# 75         333   309   313   221   101   216   182
# 79          27    37    40    29    19    21    16
# 90          93   100    96    74    62    86    69
# 120        327   276   217   192   141   222   234
# 121        133   146   171   116    70    94   118
# 126         84   104    94    74    55    88   107
# 128        130   134   106    86    90    81    82
# 130        192   149   211   199   133   203   187
# 131         73    62    42    63    37    67    58
# 147        125   152   141   117    80   158   128
# 155        259   309   325   325   240   438   437
# 192        446   395   274   247   162   322   327
# 199          7     1     1     3     5     5     7
# 226        629   626   529   493   319   517   543
# 243        629   626   529   493   319   517   543
# 245        679   699   660   567   340   533   589
# 253        383   430   450   451   258   401   427
# 273        432   409   266   241   137   250   281
# 294         93   102    95    75    61    87    72
# 310        250   236   236   268   158   267   282
# 323        142   147   169   115    83   119    95
# ...        ...   ...   ...   ...   ...   ...   ...
# 7011         0     0     0     0     0     0     0
# 7012         0     0     0     0     0     0     0
# 7013       145   145   159   153    77   121   111
# 7014       109    70    58    75    42    72    55
# 7016         0     0     0     0     0     0     0
# 7017       300   330   357   359   205   322   325
# 7018       111    63    65    68    32    84    68
# 7019       301   330   357   362   206   325   329
# 7020         0     0     0     0     0     0     0
# 7021         0     0     0     0     0     0     0
# 7022         0     0     0     0     0     0     0
# 7023        59    40    41    49    32    50    66
# 7024        73    80    76    74    30    59    69
# 7025         0     0     0     0     0     0     0
# 7026         0     0     0     0     0     0     0
# 7027         0     0     0     0     0     0     0
# 7029       145   145   159   153    77   121   111
# 7030       110    70    58    74    42    74    57
# 7031         0     0     0     0     0     0     0
# 7032       107    63    64    62    32    82    69
# 7034        49    71    83    53    38    39    29
# 7035        73    80    76    74    30    59    69
# 7037         0     0     0     0     0     0     0
# 7038       107    63    64    62    32    82    69
# 7039       121    99   137    89    48    64   115
# 7040       111    63    65    68    32    84    68
# 7041       154   139   124   107    79   102   106
# 7042         0     0     0     0     0     0     0
# 7043        90    98    99    86    32    60    70
# 7044        69    97    54    52    47   166   118
#
# [7044 rows x 7 columns]
